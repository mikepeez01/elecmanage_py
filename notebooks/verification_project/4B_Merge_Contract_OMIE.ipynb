# %%
import pandas as pd

# %%
# Parameters
tarifa = "6.2 TD"
path_contract_matrix = "c:\\Users\\mikel.perez\\0_Python_Projects - copia\\0_Python_projects_v2\\data\\customers\\elec\\Kem One\\contract_matrix_1.pkl"
path_omie_matrix = "c:\\Users\\mikel.perez\\0_Python_Projects - copia\\0_Python_projects_v2\\data\\customers\\elec\\Kem One\\omie_matrix.pkl"
path_master_matrix = "c:\\Users\\mikel.perez\\0_Python_Projects - copia\\0_Python_projects_v2\\data\\customers\\elec\\Kem One\\master_matrix_1.pkl"

# %%
# Parameters
tarifa = "6.1 TD"
path_contract_matrix = "/Users/mikelperez/0_Python_projects_v3_reduced/0_Python_projects_reduced/data/customers/elec/Generic/contract_matrix_TRIAL.pkl"
path_omie_matrix = "/Users/mikelperez/0_Python_projects_v3_reduced/0_Python_projects_reduced/data/verification_project/elec/omie_matrix.pkl"
path_master_matrix = "/Users/mikelperez/0_Python_projects_v3_reduced/0_Python_projects_reduced/data/customers/elec/Generic/master_matrix_TRIAL.pkl"

# %%
df_contract_matrix = pd.read_pickle(path_contract_matrix)
df_omie_matrix = pd.read_pickle(path_omie_matrix)

df_contract_matrix = df_contract_matrix.copy()
df_contract_matrix['date'] = df_contract_matrix['datetime'].dt.date
df_contract_matrix.drop('datetime', axis=1, inplace=True)
df_omie_matrix['date'] = df_omie_matrix['datetime'].dt.date
df_omie_matrix
# Out:
#                  datetime  periodo  value       ssaa  20_td  30_td  61_td  \
# 0     2023-01-01 00:00:00        6   0.00  26.761640  0.237  0.237  0.101
# 1     2023-01-01 01:00:00        6   0.00  27.891910  0.247  0.247  0.105
# 2     2023-01-01 02:00:00        6   0.00  38.725701  0.261  0.261  0.112
# 3     2023-01-01 03:00:00        6   0.00  38.365772  0.272  0.272  0.116
# 4     2023-01-01 04:00:00        6   0.00  40.265236  0.278  0.278  0.119
# ...                   ...      ...    ...        ...    ...    ...    ...
# 21161 2025-05-31 19:00:00        6  31.78  17.172741  0.180  0.180  0.077
# 21162 2025-05-31 20:00:00        6  62.00  15.426091  0.177  0.177  0.076
# 21163 2025-05-31 21:00:00        6  64.31  16.026816  0.179  0.179  0.077
# 21164 2025-05-31 22:00:00        6  74.44  14.124158  0.182  0.182  0.078
# 21165 2025-05-31 23:00:00        6  63.50  12.859104  0.185  0.185  0.079
#
#        62_td  63_td  64_td        date
# 0      0.071  0.058  0.022  2023-01-01
# ...

# %%
df_master = pd.merge(df_omie_matrix, df_contract_matrix, on=['date', 'periodo'], how='left')
df_master.drop('date', axis=1, inplace=True)
# quedarme con las perdidas de la tarifa correspondiente

# %%
df_master
# Out:
#                  datetime  periodo  value       ssaa  20_td  30_td  61_td  \
# 0     2023-01-01 00:00:00        6   0.00  26.761640  0.237  0.237  0.101
# 1     2023-01-01 01:00:00        6   0.00  27.891910  0.247  0.247  0.105
# 2     2023-01-01 02:00:00        6   0.00  38.725701  0.261  0.261  0.112
# 3     2023-01-01 03:00:00        6   0.00  38.365772  0.272  0.272  0.116
# 4     2023-01-01 04:00:00        6   0.00  40.265236  0.278  0.278  0.119
# ...                   ...      ...    ...        ...    ...    ...    ...
# 21161 2025-05-31 19:00:00        6  31.78  17.172741  0.180  0.180  0.077
# 21162 2025-05-31 20:00:00        6  62.00  15.426091  0.177  0.177  0.076
# 21163 2025-05-31 21:00:00        6  64.31  16.026816  0.179  0.179  0.077
# 21164 2025-05-31 22:00:00        6  74.44  14.124158  0.182  0.182  0.078
# 21165 2025-05-31 23:00:00        6  63.50  12.859104  0.185  0.185  0.079
#
#        62_td  63_td  64_td  ... tep_power_exc kp_power_exc  RECORE  Deficit  \
# ...

# %%
for col in df_master.columns:
    if '_td' in col:
        if (tarifa[0] != col[0]) or (tarifa [2] != col[1]):
            df_master.drop(col, axis=1, inplace=True)
        elif (tarifa[0] == col[0]) or (tarifa [2] == col[1]):
            df_master.rename(columns={f'{col}':'perd'}, inplace=True)

# %%
df_master
# Out:
#                  datetime  periodo  value       ssaa   perd  cliente   cups  \
# 0     2023-01-01 00:00:00        6   0.00  26.761640  0.101  Generic  TRIAL
# 1     2023-01-01 01:00:00        6   0.00  27.891910  0.105  Generic  TRIAL
# 2     2023-01-01 02:00:00        6   0.00  38.725701  0.112  Generic  TRIAL
# 3     2023-01-01 03:00:00        6   0.00  38.365772  0.116  Generic  TRIAL
# 4     2023-01-01 04:00:00        6   0.00  40.265236  0.119  Generic  TRIAL
# ...                   ...      ...    ...        ...    ...      ...    ...
# 21161 2025-05-31 19:00:00        6  31.78  17.172741  0.077  Generic  TRIAL
# 21162 2025-05-31 20:00:00        6  62.00  15.426091  0.076  Generic  TRIAL
# 21163 2025-05-31 21:00:00        6  64.31  16.026816  0.077  Generic  TRIAL
# 21164 2025-05-31 22:00:00        6  74.44  14.124158  0.078  Generic  TRIAL
# 21165 2025-05-31 23:00:00        6  63.50  12.859104  0.079  Generic  TRIAL
#
# ...

# %%
df_master.to_pickle(path_master_matrix)
